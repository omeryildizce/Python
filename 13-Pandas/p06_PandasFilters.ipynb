# %%
import pandas as pd
import numpy as np
df = pd.read_csv("imdbTop250.csv")
df
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# ...

# %%
df.columns
# Out:
# Index(['Ranking', 'IMDByear', 'IMDBlink', 'Title', 'Date', 'RunTime', 'Genre',
#        'Rating', 'Score', 'Votes', 'Gross', 'Director', 'Cast1', 'Cast2',
#        'Cast3', 'Cast4'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# ...

# %%
df.head(5)
# Out:
#    Ranking  IMDByear           IMDBlink                               Title  \
# 0        1      1996  /title/tt0076759/  Star Wars: Episode IV - A New Hope
# 1        2      1996  /title/tt0111161/            The Shawshank Redemption
# 2        3      1996  /title/tt0117951/                       Trainspotting
# 3        4      1996  /title/tt0114814/                  The Usual Suspects
# 4        5      1996  /title/tt0108598/                  The Wrong Trousers
#
#    Date  RunTime                       Genre  Rating  Score    Votes   Gross  \
# 0  1977      121  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1  1994      142                       Drama     9.3   80.0  2529673   28.34
# 2  1996       93                       Drama     8.1   83.0   665213   16.50
# 3  1995      106       Crime, Drama, Mystery     8.5   77.0  1045626   23.34
# 4  1993       30    Animation, Short, Comedy     8.3    NaN    53316     NaN
#
# ...

# %%
df.head(10)
# Out:
#    Ranking  IMDByear           IMDBlink                               Title  \
# 0        1      1996  /title/tt0076759/  Star Wars: Episode IV - A New Hope
# 1        2      1996  /title/tt0111161/            The Shawshank Redemption
# 2        3      1996  /title/tt0117951/                       Trainspotting
# 3        4      1996  /title/tt0114814/                  The Usual Suspects
# 4        5      1996  /title/tt0108598/                  The Wrong Trousers
# 5        6      1996  /title/tt0112691/                       A Close Shave
# 6        7      1996  /title/tt0117731/            Star Trek: First Contact
# 7        8      1996  /title/tt0034583/                          Casablanca
# 8        9      1996  /title/tt0083658/                        Blade Runner
# 9       10      1996  /title/tt0108052/                    Schindler's List
#
#    Date  RunTime                       Genre  Rating  Score    Votes   Gross  \
# ...

# %%
df.tail(5)
# Out:
#       Ranking  IMDByear            IMDBlink                  Title  Date  \
# 6495      246      2021   /title/tt0058946/  The Battle of Algiers  1966
# 6496      247      2021   /title/tt0050783/      Nights of Cabiria  1957
# 6497      248      2021   /title/tt0093779/     The Princess Bride  1987
# 6498      249      2021   /title/tt7060344/             Raatchasan  2018
# 6499      250      2021  /title/tt10280296/           Sardar Udham  2021
#
#       RunTime                       Genre  Rating  Score   Votes  Gross  \
# 6495      121                  Drama, War     8.1   96.0   57995   0.06
# 6496      110                       Drama     8.1    NaN   47318   0.75
# 6497       98  Adventure, Family, Fantasy     8.1   77.0  416207  30.86
# 6498      170       Crime, Drama, Mystery     8.4    NaN   37474    NaN
# 6499      164     Biography, Crime, Drama     8.7    NaN   34889    NaN
#
#               Director              Cast1              Cast2           Cast3  \
# ...

# %%
df.tail(10)
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 6490      241      2021   /title/tt0025316/
# 6491      242      2021   /title/tt0381681/
# 6492      243      2021   /title/tt0083922/
# 6493      244      2021   /title/tt0169858/
# 6494      245      2021   /title/tt0060107/
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                                Title  Date  RunTime  \
# 6490                           It Happened One Night  1934      105
# 6491                                   Before Sunset  2004       80
# 6492                             Fanny and Alexander  1982      188
# 6493  Neon Genesis Evangelion: The End of Evangelion  1997       87
# 6494                                   Andrei Rublev  1966      205
# ...

# %%
df["Title"]
# Out:
# 0       Star Wars: Episode IV - A New Hope
# 1                 The Shawshank Redemption
# 2                            Trainspotting
# 3                       The Usual Suspects
# 4                       The Wrong Trousers
#                        ...
# 6495                 The Battle of Algiers
# 6496                     Nights of Cabiria
# 6497                    The Princess Bride
# 6498                            Raatchasan
# 6499                          Sardar Udham
# Name: Title, Length: 6500, dtype: object

# %%
df["Title"].head()
# Out:
# 0    Star Wars: Episode IV - A New Hope
# 1              The Shawshank Redemption
# 2                         Trainspotting
# 3                    The Usual Suspects
# 4                    The Wrong Trousers
# Name: Title, dtype: object

# %%
df[["Title","Rating"]].head()
# Out:
#                                 Title  Rating
# 0  Star Wars: Episode IV - A New Hope     8.6
# 1            The Shawshank Redemption     9.3
# 2                       Trainspotting     8.1
# 3                  The Usual Suspects     8.5
# 4                  The Wrong Trousers     8.3

# %%
df[["Title","Rating"]].tail(7)
# Out:
#                                                Title  Rating
# 6493  Neon Genesis Evangelion: The End of Evangelion     8.1
# 6494                                   Andrei Rublev     8.1
# 6495                           The Battle of Algiers     8.1
# 6496                               Nights of Cabiria     8.1
# 6497                              The Princess Bride     8.1
# 6498                                      Raatchasan     8.4
# 6499                                    Sardar Udham     8.7

# %%
a=df[["Title","Rating"]].head(10)
a.tail(5)
# Out:
#                       Title  Rating
# 5             A Close Shave     8.1
# 6  Star Trek: First Contact     7.6
# 7                Casablanca     8.5
# 8              Blade Runner     8.1
# 9          Schindler's List     8.9

# %%
df[["Title","Rating"]].head(10).tail(5)
# Out:
#                       Title  Rating
# 5             A Close Shave     8.1
# 6  Star Trek: First Contact     7.6
# 7                Casablanca     8.5
# 8              Blade Runner     8.1
# 9          Schindler's List     8.9

# %%
df[5:][["Title","Rating"]].head()
# Out:
#                       Title  Rating
# 5             A Close Shave     8.1
# 6  Star Trek: First Contact     7.6
# 7                Casablanca     8.5
# 8              Blade Runner     8.1
# 9          Schindler's List     8.9

# %%
df[df["Rating"]>7.95][["Title","Rating"]].head(50)
# Out:
#                                                 Title  Rating
# 0                  Star Wars: Episode IV - A New Hope     8.6
# 1                            The Shawshank Redemption     9.3
# 2                                       Trainspotting     8.1
# 3                                  The Usual Suspects     8.5
# 4                                  The Wrong Trousers     8.3
# 5                                       A Close Shave     8.1
# 7                                          Casablanca     8.5
# 8                                        Blade Runner     8.1
# 9                                    Schindler's List     8.9
# 10                                       Citizen Kane     8.3
# 11                                       Pulp Fiction     8.9
# 12  Dr. Strangelove or: How I Learned to Stop Worr...     8.4
# 13                                      The Godfather     9.2
# 15                                         Braveheart     8.3
# ...

# %%
df[(df["IMDByear"] >2013 ) &( df["IMDByear"] <2016) ]["Title"]
# Out:
# 4500    The Shawshank Redemption
# 4501               The Godfather
# 4502      The Godfather: Part II
# 4503             The Dark Knight
# 4504                Pulp Fiction
#                   ...
# 4995                     Solaris
# 4996                   La Strada
# 4997                 The Killing
# 4998        In the Mood for Love
# 4999                The Graduate
# Name: Title, Length: 500, dtype: object

# %%
df[(df["Votes"]>99999) | ((df["Rating"]>=8) & (df["Rating"]<=9))][["Title","Rating","Votes"]]
# Out:
#                                    Title  Rating    Votes
# 0     Star Wars: Episode IV - A New Hope     8.6  1299781
# 1               The Shawshank Redemption     9.3  2529673
# 2                          Trainspotting     8.1   665213
# 3                     The Usual Suspects     8.5  1045626
# 4                     The Wrong Trousers     8.3    53316
# ...                                  ...     ...      ...
# 6495               The Battle of Algiers     8.1    57995
# 6496                   Nights of Cabiria     8.1    47318
# 6497                  The Princess Bride     8.1   416207
# 6498                          Raatchasan     8.4    37474
# 6499                        Sardar Udham     8.7    34889
#
# [5907 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Ranking', 'IMDByear', 'IMDBlink', 'Title', 'Date', 'RunTime', 'Genre',
#        'Rating', 'Score', 'Votes', 'Gross', 'Director', 'Cast1', 'Cast2',
#        'Cast3', 'Cast4'],
#       dtype='object')
